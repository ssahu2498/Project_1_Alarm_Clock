# %%
import numpy as np
from tkinter import *
import datetime 
import winsound
import time

# %%
def set_alarm(set_alarm_timer):
    while True:
        time.sleep(1)
        current_time = datetime.datetime.now()
        now = current_time.strftime('%H:%M:%S')
        date = current_time.strftime('%d:%m:%y')
        print('set date is {}'.format(date))
        print('set time is {}'.format(now))
        if now == set_alarm_timer:
            winsound.PlaySound('Imagine Dragons - Birds.wav',winsound.SND_ASYNC)
            break

# %%
def actual_time():
    set_alarm_timer = f"{hour.get()}:{minute.get()}:{sec.get()}"
    set_alarm(set_alarm_timer)

# %% [markdown]
# ### Creating the GUI using tkinter

# %%
clock = Tk()

# %%
clock.title("Dataflair Alarm Clock")
# Out:
# ''

# %%
clock.geometry('400x200')
# Out:
# ''

# %%
time_format = Label(clock,text = "Enter time in 24 hour time format!",fg = 'red',bg = 'black',font = 'Arial').place(x=60,y=120)
addTime = Label(clock, text = 'Hour Minute Second',font = 60).place(x=110)
setYourAlarm = Label(clock,text = "When to wake you up",fg="blue",relief = "solid",font=("Helevetica",7,"bold")).place(x=0, y=29)
# The Variables we require to set the alarm(initialization):
hour = StringVar()
minute = StringVar()
sec = StringVar()
#Time required to set the alarm clock
hourTime = Entry(clock,textvariable = hour,bg = 'pink',width=15).place(x=110,y=30)
minTime = Entry(clock,textvariable = minute,bg = 'pink',width=15).place(x=150,y=30)
secTime = Entry(clock,textvariable = sec,bg='pink',width=15).place(x=200,y=30)
#To take the time input by user:
submit = Button(clock,text='Set Alarm',fg='red',width=10,command = actual_time).place(x=110,y=70)
clock.mainloop()
# Out:
# set date is 07:10:20
# set time is 11:35:07
# set date is 07:10:20
# set time is 11:35:08
# set date is 07:10:20
# set time is 11:35:09
# set date is 07:10:20
# set time is 11:35:10
# set date is 07:10:20
# set time is 11:35:11
# set date is 07:10:20
# set time is 11:35:12
# set date is 07:10:20
# set time is 11:35:13
# set date is 07:10:20
# set time is 11:35:14
# set date is 07:10:20
# set time is 11:35:15
# set date is 07:10:20
# set time is 11:35:16
# set date is 07:10:20
# set time is 11:35:17
# set date is 07:10:20
# set time is 11:35:18
# set date is 07:10:20
# set time is 11:35:19
# set date is 07:10:20
# set time is 11:35:20
# set date is 07:10:20
# set time is 11:35:21
# set date is 07:10:20
# set time is 11:35:22
# set date is 07:10:20
# set time is 11:35:23
# set date is 07:10:20
# set time is 11:35:24
# set date is 07:10:20
# set time is 11:35:25
# set date is 07:10:20
# set time is 11:35:26
# set date is 07:10:20
# set time is 11:35:27
# set date is 07:10:20
# set time is 11:35:28
# set date is 07:10:20
# set time is 11:35:29
# set date is 07:10:20
# set time is 11:35:30
# set date is 07:10:20
# set time is 11:35:31
# set date is 07:10:20
# set time is 11:35:32
# set date is 07:10:20
# set time is 11:35:33
# set date is 07:10:20
# set time is 11:35:34
# set date is 07:10:20
# set time is 11:35:35
# set date is 07:10:20
# set time is 11:35:36
# set date is 07:10:20
# set time is 11:35:37
# set date is 07:10:20
# set time is 11:35:38
# set date is 07:10:20
# set time is 11:35:39
# set date is 07:10:20
# set time is 11:35:40
# set date is 07:10:20
# set time is 11:35:41
# set date is 07:10:20
# set time is 11:35:42
# set date is 07:10:20
# set time is 11:35:43
# set date is 07:10:20
# set time is 11:35:44
# set date is 07:10:20
# set time is 11:35:45
# set date is 07:10:20
# set time is 11:35:46
# set date is 07:10:20
# set time is 11:35:47
# set date is 07:10:20
# set time is 11:35:48
# set date is 07:10:20
# set time is 11:35:49
# set date is 07:10:20
# set time is 11:35:50
# set date is 07:10:20
# set time is 11:35:51
# set date is 07:10:20
# set time is 11:35:52
# set date is 07:10:20
# set time is 11:35:53
# set date is 07:10:20
# set time is 11:35:54
# set date is 07:10:20
# set time is 11:35:55
# set date is 07:10:20
# set time is 11:35:56
# set date is 07:10:20
# set time is 11:35:57
# set date is 07:10:20
# set time is 11:35:58
# set date is 07:10:20
# set time is 11:35:59
# set date is 07:10:20
# set time is 11:36:00
